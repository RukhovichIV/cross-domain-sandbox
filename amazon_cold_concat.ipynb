# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import implicit
import scipy
import json
import math
import gzip
import tqdm
from datetime import datetime

# %%
movies_file = "Movies_and_TV.json.gz"
music_file = "Digital_Music.json.gz"

# %%
def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield json.loads(l)

def getDF(path, count=None):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
    if count is not None and i == count:
      break
  return pd.DataFrame.from_dict(df, orient='index')

# %%
music = getDF(music_file)
music = music.astype({"overall": int}).drop("reviewTime", axis=1)
# music.reviewTime = pd.to_datetime(music.reviewTime)
music.unixReviewTime = pd.to_datetime(music.unixReviewTime, unit="s")
music.image.fillna("no image", inplace=True)
music["style"] = music["style"].apply(lambda x: json.loads("{ }") if x is np.NaN else x)
music["format"] = music["style"].apply(lambda x: " Unknown" if "Format:" not in x else x["Format:"])
music.vote = pd.to_numeric(music.vote, errors="coerce").fillna(0).astype(int)

music = music.drop_duplicates(subset=["reviewerID", "asin"], keep='last')

print(music.isna().sum())
music.fillna("", inplace=True)
print(music.dtypes)
music
# Out:
# overall              0
# verified             0
# reviewerID           0
# asin                 0
# style                0
# reviewerName        78
# reviewText        1417
# summary            521
# unixReviewTime       0
# vote                 0
# image                0
# format               0
# dtype: int64
# overall                    int64
# verified                    bool
# reviewerID                object
# asin                      object
# style                     object
# reviewerName              object
# reviewText                object
# summary                   object
# unixReviewTime    datetime64[ns]
# vote                       int64
# image                     object
# format                    object
# dtype: object
#          overall  verified      reviewerID        asin  \
# 0              5      True  A1ZCPG3D3HGRSS  0001388703
# 1              5      True   AC2PL52NKPL29  0001388703
# 2              5      True  A1SUZXBDZSDQ3A  0001388703
# 3              5      True  A3A0W7FZXM0IZW  0001388703
# 4              5     False  A12R54MKO17TW0  0001388703
# ...          ...       ...             ...         ...
# 1584077        5      True   AR3KABMPL5L0O  B01HJ91P94
# 1584078        4      True  A2N53GHW73INDH  B01HJ91P94
# 1584079        5      True   ABNKLDCCVJKW1  B01HJ91P94
# 1584080        5      True   AMWSDABZWFRAT  B01HJ91IVY
# 1584081        5      True   A7K5263R5OUIP  B01HJ91IVY
#
#                              style        reviewerName  \
# 0         {'Format:': ' Audio CD'}      mark l. massey
# 1         {'Format:': ' Audio CD'}        Norma Mushen
# 2         {'Format:': ' Audio CD'}  Herbert W. Shurley
# 3         {'Format:': ' Audio CD'}      Mary M Raybell
# 4         {'Format:': ' Audio CD'}            J. Bynum
# ...                            ...                 ...
# 1584077  {'Format:': ' MP3 Music'}          Shar Solis
# 1584078  {'Format:': ' MP3 Music'}              PEANUT
# 1584079  {'Format:': ' MP3 Music'}                Alex
# 1584080  {'Format:': ' MP3 Music'}         sara cabuag
# 1584081  {'Format:': ' MP3 Music'}          K. Elliott
#
#                                                 reviewText  \
# 0        This is a great cd full of worship favorites!!...
# 1        So creative!  Love his music - the words, the ...
# 2        Keith Green, gone far to early in his carreer,...
# 3        Keith Green had his special comedy style of Ch...
# 4        Keith Green / So you wanna go back to Egypt......
# ...                                                    ...
# 1584077  Casting Crowns....you do it so well! Awesome s...
# 1584078  This band has produced many inspiring Christia...
# 1584079  Awesome band and awesome song. This is my next...
# 1584080                                          Excellent
# 1584081  This is a moving song. I used it on Easter mor...
#
#                                                    summary unixReviewTime  \
# 0                                         Great worship cd     2013-12-22
# 1                                    Gotta listen to this!     2013-09-11
# 2                Great approach still gets the message out     2013-03-02
# 3                                        Great A must have     2012-12-02
# 4        A great one from Keith with a guest appearance...     2012-01-07
# ...                                                    ...            ...
# 1584077                                      Awesome song!     2018-03-03
# 1584078  This song in particular speaks about what it's...     2018-01-24
# 1584079                                         Five Stars     2017-04-21
# 1584080                                         Five Stars     2018-02-23
# 1584081                      Casting Crowns does it again!     2017-05-17
#
#          vote     image      format
# 0           0  no image    Audio CD
# 1           0  no image    Audio CD
# 2           0  no image    Audio CD
# 3           0  no image    Audio CD
# 4           6  no image    Audio CD
# ...       ...       ...         ...
# 1584077     0  no image   MP3 Music
# 1584078     0  no image   MP3 Music
# 1584079     0  no image   MP3 Music
# 1584080     0  no image   MP3 Music
# 1584081     0  no image   MP3 Music
#
# [1516551 rows x 12 columns]

# %%
movies = getDF(movies_file)  # , count=2000000)
movies = movies.astype({"overall": int}).drop("reviewTime", axis=1)
# movies.reviewTime = pd.to_datetime(movies.reviewTime)
movies.unixReviewTime = pd.to_datetime(movies.unixReviewTime, unit="s")
movies.image.fillna("no image", inplace=True)
movies["style"] = movies["style"].apply(lambda x: json.loads("{ }") if x is np.NaN else x)
movies["format"] = movies["style"].apply(lambda x: " Unknown" if "Format:" not in x else x["Format:"])
movies.vote = pd.to_numeric(movies.vote, errors="coerce").fillna(0).astype(int)

movies = movies.drop_duplicates(subset=["reviewerID", "asin"], keep='last')

print(movies.isna().sum())
movies.fillna("", inplace=True)
print(movies.dtypes)
movies
# Out:
# overall              0
# verified             0
# reviewerID           0
# asin                 0
# style                0
# reviewerName       258
# reviewText        7833
# summary           2138
# unixReviewTime       0
# vote                 0
# image                0
# format               0
# dtype: int64
# overall                    int64
# verified                    bool
# reviewerID                object
# asin                      object
# style                     object
# reviewerName              object
# reviewText                object
# summary                   object
# unixReviewTime    datetime64[ns]
# vote                       int64
# image                     object
# format                    object
# dtype: object
#          overall  verified      reviewerID        asin  \
# 0              5      True  A3478QRKQDOPQ2  0001527665
# 1              5      True  A2VHSG6TZHU1OB  0001527665
# 2              5     False  A23EJWOW1TLENE  0001527665
# 3              5      True  A1KM9FNEJ8Q171  0001527665
# 4              4      True  A38LY2SSHVHRYB  0001527665
# ...          ...       ...             ...         ...
# 8765563        5     False  A29XKBB6SEYTN6  B01HJ6R77G
# 8765564        4     False   ASEBX8TBYWQWA  B01HJ6R77G
# 8765565        1      True   AK4XZBLSY1WC9  B01HJCCLOY
# 8765566        3      True   AK19IXB9I4175  B01HJCCLOY
# 8765567        5     False  A1S0SJUFEGOC8J  B01HJF79XO
#
#                                 style         reviewerName  \
# 0            {'Format:': ' VHS Tape'}                jacki
# 1        {'Format:': ' Amazon Video'}                Ken P
# 2        {'Format:': ' Amazon Video'}        Reina Berumen
# 3        {'Format:': ' Amazon Video'}              N Coyle
# 4        {'Format:': ' Amazon Video'}         Jodie Vesely
# ...                               ...                  ...
# 8765563           {'Format:': ' DVD'}         Tommy Dooley
# 8765564           {'Format:': ' DVD'}           Steve Ramm
# 8765565                            {}       John R. Norene
# 8765566                            {}                  GJR
# 8765567       {'Format:': ' Blu-ray'}  B. Sounthonevichith
#
#                                                 reviewText  \
# 0        really happy they got evangelised .. spoiler a...
# 1        Having lived in West New Guinea (Papua) during...
# 2        Excellent look into contextualizing the Gospel...
# 3        More than anything, I've been challenged to fi...
# 4        This is a great movie for a missionary going i...
# ...                                                    ...
# 8765563  Set in a non existent country we meet El Presi...
# 8765564  This 2014 film is just being released on DVD i...
# 8765565  Instead of dealing with the legend in a manner...
# 8765566  My review is of the technical aspects of "She....
# 8765567  This movie is awesome and definitely worth the...
#
#                                                    summary unixReviewTime  \
# 0                                                    great     2013-03-11
# 1                                   Realistic and Accurate     2013-02-18
# 2                                              Peace Child     2013-01-17
# 3        Culturally relevant ways to share the love of ...     2013-01-10
# 4        Good Movie! Great for cross-cultural missionar...     2012-12-26
# ...                                                    ...            ...
# 8765563      A Great Polemic against dictators everywhere.     2017-04-12
# 8765564  Georgian-French film by Iranian Director is a ...     2016-08-30
# 8765565                                        Poorly done     2017-05-24
# 8765566               No Chapters, No Subtitles, No Extras     2017-04-13
# 8765567                                            Awesome     2016-11-12
#
#          vote                                              image  \
# 0           0                                           no image
# 1           3                                           no image
# 2           0                                           no image
# 3           0                                           no image
# 4           0                                           no image
# ...       ...                                                ...
# 8765563     0                                           no image
# 8765564     0                                           no image
# 8765565     0                                           no image
# 8765566     0                                           no image
# 8765567     5  [https://images-na.ssl-images-amazon.com/image...
#
#                 format
# 0             VHS Tape
# 1         Amazon Video
# 2         Amazon Video
# 3         Amazon Video
# 4         Amazon Video
# ...                ...
# 8765563            DVD
# 8765564            DVD
# 8765565        Unknown
# 8765566        Unknown
# 8765567        Blu-ray
#
# [8506849 rows x 12 columns]

# %%
music_reviewers = set(music.reviewerID.values)
movie_reviewers = set(movies.reviewerID.values)
print(f"Movie users: {len(movie_reviewers)}")
print(f"Music users: {len(music_reviewers)}")
in_movies_from_music = movies.loc[movies.reviewerID.apply(lambda x: x in music_reviewers),:]
in_music_from_movies = music.loc[music.reviewerID.apply(lambda x: x in movie_reviewers),:]
cross_reviewers = set(in_music_from_movies.reviewerID.values)
print(f"Cross users: {len(cross_reviewers)}")
print(f"{len(in_movies_from_music.reviewerID.unique()) / len(movie_reviewers) * 100:.3f}% of movie reviewers")
print(f"{len(in_movies_from_music.reviewerID.unique()) / len(music_reviewers) * 100:.3f}% of music reviewers")
in_music_from_movies
# Out:
# Movie users: 3826085
# Music users: 840372
# Cross users: 260039
# 6.796% of movie reviewers
# 30.943% of music reviewers
#          overall  verified      reviewerID        asin  \
# 0              5      True  A1ZCPG3D3HGRSS  0001388703
# 2              5      True  A1SUZXBDZSDQ3A  0001388703
# 3              5      True  A3A0W7FZXM0IZW  0001388703
# 4              5     False  A12R54MKO17TW0  0001388703
# 7              5     False   AT7OB43GHKIUA  0001388703
# ...          ...       ...             ...         ...
# 1584061        4     False   ALQ12GYW884EJ  B01HJ90892
# 1584064        5      True  A1K0WGNA0PRPJ0  B01HJ8ZXRK
# 1584072        5      True  A10AMVCF9YOWHL  B01HJ904F0
# 1584078        4      True  A2N53GHW73INDH  B01HJ91P94
# 1584081        5      True   A7K5263R5OUIP  B01HJ91IVY
#
#                              style          reviewerName  \
# 0         {'Format:': ' Audio CD'}        mark l. massey
# 2         {'Format:': ' Audio CD'}    Herbert W. Shurley
# 3         {'Format:': ' Audio CD'}        Mary M Raybell
# 4         {'Format:': ' Audio CD'}              J. Bynum
# 7         {'Format:': ' Audio CD'}      William G. Simon
# ...                            ...                   ...
# 1584061  {'Format:': ' MP3 Music'}  Manuel Grosso Galvan
# 1584064  {'Format:': ' MP3 Music'}           Retired Mom
# 1584072  {'Format:': ' MP3 Music'}          Dark McGwire
# 1584078  {'Format:': ' MP3 Music'}                PEANUT
# 1584081  {'Format:': ' MP3 Music'}            K. Elliott
#
#                                                 reviewText  \
# 0        This is a great cd full of worship favorites!!...
# 2        Keith Green, gone far to early in his carreer,...
# 3        Keith Green had his special comedy style of Ch...
# 4        Keith Green / So you wanna go back to Egypt......
# 7        Keith Green is a bit of legend in some Christi...
# ...                                                    ...
# 1584061  Lives concerts in Europe in 2011. Great materi...
# 1584064  Her music is inspiring and uplifting -great ta...
# 1584072  This is very good music!! Takes me back to the...
# 1584078  This band has produced many inspiring Christia...
# 1584081  This is a moving song. I used it on Easter mor...
#
#                                                    summary unixReviewTime  \
# 0                                         Great worship cd     2013-12-22
# 2                Great approach still gets the message out     2013-03-02
# 3                                        Great A must have     2012-12-02
# 4        A great one from Keith with a guest appearance...     2012-01-07
# 7        Heartfelt, Passionate and Funny - Green is Mas...     2008-05-04
# ...                                                    ...            ...
# 1584061  Great material, both musician are really good ...     2016-09-20
# 1584064                                          Must have     2016-08-21
# 1584072                                         Five Stars     2016-11-15
# 1584078  This song in particular speaks about what it's...     2018-01-24
# 1584081                      Casting Crowns does it again!     2017-05-17
#
#          vote     image      format
# 0           0  no image    Audio CD
# 2           0  no image    Audio CD
# 3           0  no image    Audio CD
# 4           6  no image    Audio CD
# 7          10  no image    Audio CD
# ...       ...       ...         ...
# 1584061     0  no image   MP3 Music
# 1584064     2  no image   MP3 Music
# 1584072     0  no image   MP3 Music
# 1584078     0  no image   MP3 Music
# 1584081     0  no image   MP3 Music
#
# [639049 rows x 12 columns]

# %%
movie_items = set(movies.asin.values)
music_items = set(music.asin.values)
print(f"Movie items: {len(movie_items)}")
print(f"Music items: {len(music_items)}")
# Out:
# Movie items: 182032
# Music items: 456992

# %%
only_movie_reviewers_id = movie_reviewers.difference(cross_reviewers)
only_movie_reviewers_matrix = movies.loc[[True if reviewer in only_movie_reviewers_id else False for reviewer in movies.reviewerID], :]
only_movie_reviewers_map = {val: i for i, val in enumerate(only_movie_reviewers_id)}
movie_items_map = {val: i for i, val in enumerate(movie_items)}
MoX = scipy.sparse.csr_matrix((only_movie_reviewers_matrix.overall,
                              ([only_movie_reviewers_map[elem] for elem in only_movie_reviewers_matrix.reviewerID],
                               [movie_items_map[elem] for elem in only_movie_reviewers_matrix.asin])),
                              dtype=np.uint8,
                              shape=(len(only_movie_reviewers_id), len(movie_items) + len(music_items)))
MoX
# Out:
# <3566046x639024 sparse matrix of type '<class 'numpy.uint8'>'
# 	with 7141833 stored elements in Compressed Sparse Row format>

# %%
only_music_reviewers_id = music_reviewers.difference(cross_reviewers)
only_music_reviewers_matrix = music.loc[[True if reviewer in only_music_reviewers_id else False for reviewer in music.reviewerID], :]
only_music_reviewers_map = {val: i for i, val in enumerate(only_music_reviewers_id)}
music_items_map = {val: i for i, val in enumerate(music_items)}
MuX = scipy.sparse.csr_matrix((only_music_reviewers_matrix.overall,
                              ([only_music_reviewers_map[elem] for elem in only_music_reviewers_matrix.reviewerID],
                               [len(movie_items) + music_items_map[elem] for elem in only_music_reviewers_matrix.asin])),
                              dtype=np.uint8,
                              shape=(len(only_music_reviewers_id), len(movie_items) + len(music_items)))
MuX
# Out:
# <580333x639024 sparse matrix of type '<class 'numpy.uint8'>'
# 	with 877502 stored elements in Compressed Sparse Row format>

# %%
cross_reviewers_movie_matrix = movies.loc[[True if reviewer in cross_reviewers else False for reviewer in movies.reviewerID], :]
cross_reviewers_music_matrix = music.loc[[True if reviewer in cross_reviewers else False for reviewer in music.reviewerID], :]
cross_reviewers_map = {val: i for i, val in enumerate(cross_reviewers)}
CrMoX = scipy.sparse.csr_matrix((cross_reviewers_movie_matrix.overall,
                                ([cross_reviewers_map[elem] for elem in cross_reviewers_movie_matrix.reviewerID],
                                 [movie_items_map[elem] for elem in cross_reviewers_movie_matrix.asin])),
                                dtype=np.uint8,
                                shape=(len(cross_reviewers), len(movie_items)))
CrMuX = scipy.sparse.csr_matrix((cross_reviewers_music_matrix.overall,
                                ([cross_reviewers_map[elem] for elem in cross_reviewers_music_matrix.reviewerID],
                                 [music_items_map[elem] for elem in cross_reviewers_music_matrix.asin])),
                                dtype=np.uint8,
                                shape=(len(cross_reviewers), len(music_items)))
CrX = scipy.sparse.hstack([CrMoX, CrMuX]).tocsr()
CrX
# Out:
# <260039x639024 sparse matrix of type '<class 'numpy.uint8'>'
# 	with 2004065 stored elements in Compressed Sparse Row format>

# %%
X = CrX
print(set(X.data))  # Must be [1; 5]
X
# Out:
# {1, 2, 3, 4, 5}
# <260039x639024 sparse matrix of type '<class 'numpy.uint8'>'
# 	with 2004065 stored elements in Compressed Sparse Row format>

# %%
from sklearn.model_selection import ShuffleSplit
random_state = 12345
at = 10

split = ShuffleSplit(n_splits=1, test_size=0.2, random_state=random_state)
for train, test in split.split(X):
    print(test)
    X_train_part = X[train]
    X_test_part = scipy.sparse.hstack([CrMoX[test], scipy.sparse.csr_matrix((test.shape[0], CrMuX.shape[1]))]).tocsr()
    X_train = scipy.sparse.vstack([X_test_part, X_train_part]).tocsr()  # concatenated matrix, test subsample of music set to 0
    X_test = CrMuX[test]                                                # test subsample of music
X_train
# Out:
# [125149 207500 164881 ... 150908 185817 130308]
# <260039x639024 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1877619 stored elements in Compressed Sparse Row format>

# %%
# !export MKL_NUM_THREADS=1
# !export OPENBLAS_NUM_THREADS=1

model = implicit.als.AlternatingLeastSquares(factors=20, dtype=np.float32, use_gpu=False, iterations=20,
                                             calculate_training_loss=True, num_threads=16, random_state=random_state)
model.fit(X_train.T)
# Out:
# WARNING:root:OpenBLAS detected. Its highly recommend to set the environment variable 'export OPENBLAS_NUM_THREADS=1' to disable its internal multithreading
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
music_item_embeddings = model.item_factors[CrMoX.shape[1]:]
music_item_embeddings.shape
# Out:
# (456992, 20)

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=at, algorithm="kd_tree", n_jobs=16)
neigh.fit(music_item_embeddings,y=[0] * music_item_embeddings.shape[0])
# Out:
# KNeighborsClassifier(algorithm='kd_tree', n_jobs=16, n_neighbors=10)

# %%
idcg = 0
for i in range(at):
    idcg += 1/math.log2(i + 2)

for train, test in split.split(X):
    map = 0
    mean_ndcg = 0
    test_users_embeddings = model.user_factors[:X_test.shape[0]]

    with tqdm.tqdm(total=X_test.shape[0]) as it:
        for i, row in enumerate(X_test):
            relevant_items = row.indices[row.data > 3]
            recommendation = neigh.kneighbors([test_users_embeddings[i]], n_neighbors=at, return_distance=False)[0]

            num_relevant = 0
            dcg = 0
            for i, rec in enumerate(recommendation):
                if rec in relevant_items:
                    num_relevant += 1
                    dcg += 1/math.log2(i + 2)

            map += num_relevant / at
            mean_ndcg += dcg
            it.update(1)
    map /= X_test.shape[0]
    mean_ndcg /= X_test.shape[0] * idcg

    print(f"{X_test.shape[0]} users taken")
    print(f"MAP@{at}: {map}")
    print(f"Mean NDCG@{at}: {mean_ndcg}")
# Out:
# 100%|██████████| 52008/52008 [08:23<00:00, 103.25it/s]
# 52008 users taken
# MAP@10: 9.229349330872174e-05
# Mean NDCG@10: 0.00010616310978825189
